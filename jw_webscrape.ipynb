# %% [markdown]
# # Scrape for movie info

# %%
# Jurassic World url http://www.boxofficemojo.com/movies/?id=jurassicpark4.htm

# %%
#import requests

#url = 'http://www.boxofficemojo.com/movies/?id=jurassicpark4.htm'

#response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
import dill as pickle
import pandas

# %%
#with open('jw_webpage.pkl', 'w') as picklefile:
#    pickle.dump(response, picklefile)

# %%
with open("jw_webpage.pkl", 'r') as picklefile: 
    response = pickle.load(picklefile)

# %%
page = response.text

from bs4 import BeautifulSoup

soup = BeautifulSoup(page)

# %%
jw_tables = soup.find_all('table')

# %%
jw_tables
# Out:
# [<table border="0" cellspacing="0" width="878px">
#  <tr>
#  <td align="right" style="whitespace:nowrap;">
#  <table border="0" cellpadding="0" cellspacing="0">
#  <tr>
#  <form action="/adjuster.php" method="POST" name="adjuster">
#  <input name="returnURL" type="hidden" value="/movies/?id=jurassicpark4.htm"/>
#  <td valign="center">
#  <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
#  <select name="ticketyr" size="1" style="font-family: Verdana; font-size: 10pt">
#  <option selected="" value="0">Actuals</option>
#  <option value="1">Est. Tckts</option>
#  <script language="javascript">
#    for(i=2015; i>=1933; i--) {
#    	document.write('<option value="' + i + '"');
#  	if(i=='0') document.write(' selected');
#  	document.write('>' + i );
#  	if(i=='0') document.write(', $' + '0.00');
#  	document.write('</option>');
#    }
#  </script>
#  <option value="1929">1929</option>
#  <option value="1924">1924</option>
# ...

# %%
soup.find("div", { "class" : "mp_box_content" }).parent.next_sibling.next_sibling
# Out:
# <div class="mp_box">
# <div class="mp_box_tab">Domestic Summary</div>
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="center"><a href="/weekend/chart/?yr=2015&amp;wknd=24&amp;p=.htm">Opening Weekend:</a></td><td> $208,806,270</td></tr>
# <tr>
# <td align="center" colspan="2"><font size="2">(#1 rank, 4,274 theaters, $48,855 average)</font></td></tr>
# <tr>
# <td align="right">% of Total Gross:</td><td> 32.1%</td></tr>
# <tr><td align="right" colspan="2"><font face="Helvetica, Arial, Sans-Serif" size="1"><a href="/movies/?page=weekend&amp;id=jurassicpark4.htm"><b>&gt; View All 16 Weekends</b></a></font></td></tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td>Widest Release:</td>
# <td> 4,291 theaters</td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td>In Release:</td>
# <td> 110 days / 15.7 weeks</td>
# </tr>
# </table>
# </div>
# </div>

# %%
soup.find(text = 'The Players').parent.parent.find_all('table')[0].find_all('tr')
# Out:
# [<tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Director&amp;p=.htm">Director:</a></font></td><td><font size="2"><a href="/people/chart/?view=Director&amp;id=colintrevorrow.htm">Colin Trevorrow</a></font></td></tr>,
#  <tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Writer&amp;p=.htm">Writers:</a></font></td><td><font size="2"><a href="/people/chart/?view=Writer&amp;id=derekconnolly.htm">Derek Connolly</a><br/><a href="/people/chart/?view=Writer&amp;id=rickjaffa.htm">Rick Jaffa</a><br/><a href="/people/chart/?view=Writer&amp;id=amandasilver.htm">Amanda Silver</a><br/><a href="/people/chart/?view=Writer&amp;id=colintrevorrow.htm">Colin Trevorrow</a></font></td></tr>,
# ...

# %%
soup.find(text = 'The Players').parent.parent.find_all('table')[0].find_all('tr')[1].a['href']
# Out:
# '/people/?view=Writer&p=.htm'

# %%
def movie_table(all_movie_html_block):
    movie_table = []
    movie_html_block = []
    movie_attribute = []
    movie_items = []
    contributor_desc = ""
    for x in range(0, len(all_movie_html_block)):
        movie_items = [] #this is cleared out as we reloop through the list to append new individual movie attributes
        movie_html_block = all_movie_html_block[x] #individual blocks from all_movie_html_block
        for i in range(1, len(movie_html_block[x])):
            print i.find_all('a').text
            
            
            '''
            movie_role = movie_html_block.find_all('tr')[0].find_all('a')[0].text
            movie_attribute = movie_html_block.find_all('tr')[x].find_all('a')[i].text
            movie_items.append(movie_attribute)
            try:
                movie_html = movie_html_block.find_all('tr')[i].a['href']
            except:
                movie_html = ""
            movie_items.append(movie_html)
        movie_table.append(movie_items)
    return movie_table
    '''

# %%
movie_desc_block = soup.find(text = 'The Players').parent.parent.find_all('table')[0].find_all('tr')

# %%
temp = movie_table(movie_desc_block)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-12559e33d824> in <module>()
# ----> 1 temp = movie_table(movie_desc_block)
#
# <ipython-input-98-c373bec95b39> in movie_table(all_movie_html_block)
#       8         movie_items = [] #this is cleared out as we reloop through the list to append new individual movie attributes
#       9         movie_html_block = all_movie_html_block[x] #individual blocks from all_movie_html_block
# ---> 10         for i in range(1, len(movie_html_block[x])):
#      11             print i.find_all('a').text
#      12
#
# /Users/johnwalters/anaconda/lib/python2.7/site-packages/bs4/element.pyc in __getitem__(self, key)
#     903         """tag[key] returns the value of the 'key' attribute for the tag,
#     904         and throws an exception if it's not there."""
# --> 905         return self.attrs[key]
#     906
# ...

# %%
temp
# Out:
# [[], [], [], [], []]

# %%
soup.find(text = 'The Players').parent.parent.find_all('table')[0].find_all('tr')[1].find_all('a')[1].text
# Out:
# u'Derek Connolly'
