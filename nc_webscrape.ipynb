# %%
#import requests

#url = 'http://www.boxofficemojo.com/people/chart/?id=nicolascage.htm'

#response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
import dill as pickle
import pandas

# %%
#with open('nc_webpage.pkl', 'w') as picklefile:
#    pickle.dump(response, picklefile)

# %%
with open("nc_webpage.pkl", 'r') as picklefile: 
    response = pickle.load(picklefile)

# %%
print response.text
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <HEAD>
# <TITLE>Nicolas Cage Movie Box Office Results</TITLE>
# <META name="description" content="Nicolas Cage box office breakdown and upcoming movies.">
# <META name="keywords" content="Nicolas Cage, Actor, box, office, history, result, number, movie, film, filmography, data">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="screen" title="no title" charset="utf-8">
# <link rel="stylesheet" href="/css/mojo.css?1" type="text/css" media="print" title="no title" charset="utf-8"></head>
# <body>
# <iframe id="sis_pixel_sitewide" width="1" height="1" frameborder="0" marginwidth="0" marginheight="0" style="display: none;"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = 'http://s.amazon-adsystem.com/iu3?',
# ...

# %%
page = response.text

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page)

# %%
print soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <title>Nicolas Cage Movie Box Office Results</title>
# <meta content="Nicolas Cage box office breakdown and upcoming movies." name="description"/>
# <meta content="Nicolas Cage, Actor, box, office, history, result, number, movie, film, filmography, data" name="keywords"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/></head>
# <body>
# <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
# ...

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
#  <head>
#   <title>
#    Nicolas Cage Movie Box Office Results
#   </title>
#   <meta content="Nicolas Cage box office breakdown and upcoming movies." name="description"/>
#   <meta content="Nicolas Cage, Actor, box, office, history, result, number, movie, film, filmography, data" name="keywords"/>
#   <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
#   <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/>
#  </head>
#  <body>
#   <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1">
#   </iframe>
#   <script>
#    setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
# ...

# %%
print soup.find_all(text = 'Nicolas Cage')
# Out:
# [u'Nicolas Cage']

# %%
print soup.find(text = 'Nicolas Cage').parent
# Out:
# <h1>Nicolas Cage</h1>

# %%
nc_name = soup.h1.text

# %%
print soup.find_all(text = 'Left Behind (2014)')[0].parent.parent
# Out:
# <a href="/movies/?id=leftbehind2014.htm"><b>Left Behind (2014)</b></a>

# %%
nc_tables = soup.find_all('table')

# %%
nc_tables.find(text = 'Left Behind (2014)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-478c91950e2f> in <module>()
# ----> 1 nc_tables.find(text = 'Left Behind (2014)')
#
# AttributeError: 'ResultSet' object has no attribute 'find'

# %%
movie_line = soup.find_all('table')[1].find_all('tr')[0].find_all('td')[0].find_all('tr')
print movie_line
# Out:
# [<tr bgcolor="#dcdcdc"><td align="center"><font size="2"><a href="/people/chart/?view=Actor&amp;id=nicolascage.htm&amp;sort=date&amp;order=ASC&amp;p=.htm"><b>Date</b></a></font></td><td align="center"><font size="2"><a href="/people/chart/?view=Actor&amp;id=nicolascage.htm&amp;sort=title&amp;order=ASC&amp;p=.htm">Title (click to view)</a></font></td><td align="center"><font size="2"><a href="/people/chart/?view=Actor&amp;id=nicolascage.htm&amp;sort=studio&amp;order=ASC&amp;p=.htm">Studio</a></font></td><td align="center" colspan="2"><font size="2"><a href="/people/chart/?view=Actor&amp;id=nicolascage.htm&amp;sort=gross&amp;order=DESC&amp;p=.htm">Lifetime Gross</a> / </font><font size="2"><a href="/people/chart/?view=Actor&amp;id=nicolascage.htm&amp;sort=maxtheaters&amp;order=DESC&amp;p=.htm">Theaters</a></font></td><td align="center" colspan="2"><font size="2"><a href="/people/chart/?view=Actor&amp;id=nicolascage.htm&amp;sort=opengross&amp;order=DESC&amp;p=.htm">Opening</a> / </font>
# ...

# %%
print movie_line.find_all('td')[0].text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-5ff4f9524196> in <module>()
# ----> 1 print movie_line.find_all('td')[0].text
#
# AttributeError: 'ResultSet' object has no attribute 'find_all'

# %%
movie_list = []

for i in range(len(movie_line.find_all('td'))):
    movie_element = movie_line.find_all('td')[i].text
    movie_list.append(movie_element)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-40ae9a1c3cbd> in <module>()
#       1 movie_list = []
#       2
# ----> 3 for i in range(len(movie_line.find_all('td'))):
#       4     movie_element = movie_line.find_all('td')[i].text
#       5     movie_list.append(movie_element)
#
# AttributeError: 'ResultSet' object has no attribute 'find_all'

# %%
all_movie_html_block = soup.find_all('table')[1].find_all('tr')[0].find_all('td')[0].find_all('tr')

# %%
# loops through our issolated table of all movies to return their details
movie_table = [] #this is created as an empty list so we can append new items to the movie table
for x in range(1, len(all_movie_html_block)):
    movie_items = [] #this is cleared out as we reloop through the list to append new individual movie attributes
    movie_html_block = all_movie_html_block[x] #individual blocks from all_movie_html_block
    for i in range(len(movie_html_block.find_all('td'))):
        movie_attribute = movie_html_block.find_all('td')[i].text
        movie_items.append(movie_attribute)
    movie_table.append(movie_items)

# %%
movie_table
# Out:
# [[u'10/3/14',
#   u'Left Behind (2014)',
#   u'Free',
#   u'$14,019,924',
#   u'1,887',
#   u'$6,300,147',
#   u'1,825',
#   u'41'],
#  [u'4/11/14',
#   u'Joe (2014)',
#   u'RAtt.',
#   u'$373,375',
#   u'48',
#   u'$105,881',
#   u'48',
#   u'52'],
#  [u'3/22/13',
#   u'The Croods(Voice)',
#   u'Fox',
#   u'$187,168,425',
#   u'4,065',
#   u'$43,639,736',
#   u'4,046',
#   u'2'],
#  [u'9/14/12',
#   u'Stolen (2012)',
#   u'MNE',
#   u'$304,318',
#   u'141',
#   u'$183,125',
#   u'141',
#   u'53'],
#  [u'3/16/12',
#   u'Seeking Justice',
#   u'Anch.',
#   u'$411,746',
#   u'231',
#   u'$249,912',
#   u'231',
#   u'51'],
#  [u'2/17/12',
#   u'Ghost Rider: Spirit of Vengeance',
#   u'Sony',
#   u'$51,774,002',
#   u'3,174',
#   u'$22,115,334',
#   u'3,174',
#   u'16'],
#  [u'10/14/11',
#   u'Trespass (2011)',
#   u'MNE',
#   u'$24,094',
#   u'10',
#   u'$16,816',
#   u'10',
#   u'55'],
#  [u'2/25/11',
#   u'Drive Angry',
#   u'Sum.',
#   u'$10,721,033',
#   u'2,290',
# ...

# %%
import pandas as pd

# %%
col = ['date', 'movie_name', 'studio', 'gross', 'theaters_g', 'opening', 'theaters_o', 'rank']
nc_movies = pd.DataFrame(movie_table, columns = col)

# %%
nc_movies
# Out:
#         date                                movie_name  studio         gross  \
# 0    10/3/14                        Left Behind (2014)    Free   $14,019,924
# 1    4/11/14                                Joe (2014)   RAtt.      $373,375
# 2    3/22/13                         The Croods(Voice)     Fox  $187,168,425
# 3    9/14/12                             Stolen (2012)     MNE      $304,318
# 4    3/16/12                           Seeking Justice   Anch.      $411,746
# 5    2/17/12          Ghost Rider: Spirit of Vengeance    Sony   $51,774,002
# 6   10/14/11                           Trespass (2011)     MNE       $24,094
# 7    2/25/11                               Drive Angry    Sum.   $10,721,033
# 8     1/7/11                       Season of the Witch   Rela.   $24,827,228
# 9    7/14/10                 The Sorcerer's Apprentice      BV   $63,150,991
# 10   4/16/10                                  Kick-Ass     LGF   $48,071,303
# ...

# %% [markdown]
# ### Now I will check the second table for adjusted gross

# %%
soup.find_all('table')[3].find_all('tr')[1].find_all('td')
#this is the parsed data where the "movie_html_block" lives
# Out:
# [<td align="center"><font size="2">1</font></td>,
#  <td><font size="2"><a href="/movies/?id=nationaltreasure2.htm"><b>National Treasure: Book of Secrets</b></a></font></td>,
#  <td><font size="2"><a href="/studio/chart/?studio=buenavista.htm">BV</a></font></td>,
#  <td align="right"><font size="2"><b>$261,537,700</b></font></td>,
#  <td align="right"><font size="2">$219,964,115</font></td>,
#  <td align="right"><font size="2"><a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=2007-12-21&amp;p=.htm">12/21/07</a></font></td>]

# %%
for x in range(1, len(soup.find_all('table')[3].find_all('tr'))):
    #print x.text
    for i in soup.find_all('table')[0].find_all('tr')[x]:
        print i
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-959ea5f380f2> in <module>()
#       1 for x in range(1, len(soup.find_all('table')[3].find_all('tr'))):
#       2     #print x.text
# ----> 3     for i in soup.find_all('table')[0].find_all('tr')[x]:
#       4         print i
#
# IndexError: list index out of range

# %%
all_movie_html_block_adj = soup.find_all('table')[3].find_all('tr')
all_movie_html_block_adj
# Out:
# [<tr bgcolor="#dcdcdc"><td align="center"><font size="2">Rank</font></td><td align="center"><font size="2">Title (click to view)</font></td><td align="center"><font size="2">Studio</font></td><td align="center"><font size="2">Adjusted Gross</font></td><td align="center"><font size="2">Unadjusted Gross</font></td><td align="center"><font size="2">Release</font></td></tr>,
#  <tr bgcolor="#ffffff"><td align="center"><font size="2">1</font></td>
#  <td><font size="2"><a href="/movies/?id=nationaltreasure2.htm"><b>National Treasure: Book of Secrets</b></a></font></td>
#  <td><font size="2"><a href="/studio/chart/?studio=buenavista.htm">BV</a></font></td>
#  <td align="right"><font size="2"><b>$261,537,700</b></font></td>
#  <td align="right"><font size="2">$219,964,115</font></td>
#  <td align="right"><font size="2"><a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=2007-12-21&amp;p=.htm">12/21/07</a></font></td>
#  </tr>,
# ...

# %%
def adj_table(all_movie_html_block_adj):
    movie_table = []
    movie_html_block = []
    movie_attribute = []
    movie_items = []
    for x in range(1, len(all_movie_html_block_adj)):
        movie_items = [] #this is cleared out as we reloop through the list to append new individual movie attributes
        movie_html_block = all_movie_html_block_adj[x] #individual blocks from all_movie_html_block
        for i in range(0, len(movie_html_block.find_all('td'))):
            movie_attribute = movie_html_block.find_all('td')[i].text
            movie_items.append(movie_attribute)
        movie_table.append(movie_items)
    return movie_table

# %%
soup.find_all('table')[3].find_all('tr')[1].find_all('td')
# Out:
# [<td align="center"><font size="2">1</font></td>,
#  <td><font size="2"><a href="/movies/?id=nationaltreasure2.htm"><b>National Treasure: Book of Secrets</b></a></font></td>,
#  <td><font size="2"><a href="/studio/chart/?studio=buenavista.htm">BV</a></font></td>,
#  <td align="right"><font size="2"><b>$261,537,700</b></font></td>,
#  <td align="right"><font size="2">$219,964,115</font></td>,
#  <td align="right"><font size="2"><a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=2007-12-21&amp;p=.htm">12/21/07</a></font></td>]

# %%
movie_table = adj_table(all_movie_html_block_adj)

# %%
movie_table
# Out:
# [[u'1',
#   u'National Treasure: Book of Secrets',
#   u'BV',
#   u'$261,537,700',
#   u'$219,964,115',
#   u'12/21/07'],
#  [u'2', u'The Rock', u'BV', u'$254,489,400', u'$134,069,511', u'6/7/96'],
#  [u'3',
#   u'National Treasure',
#   u'BV',
#   u'$232,678,500',
#   u'$173,008,894',
#   u'11/19/04'],
#  [u'4', u'Face/Off', u'Par.', u'$205,228,100', u'$112,276,146', u'6/27/97'],
#  [u'5', u'The Croods', u'Fox', u'$190,841,800', u'$187,168,425', u'3/22/13'],
#  [u'6', u'Con Air', u'BV', u'$184,831,400', u'$101,117,573', u'6/6/97'],
#  [u'7', u'Moonstruck', u'MGM', u'$164,679,900', u'$80,640,528', u'12/18/87'],
#  [u'8',
#   u'Gone in 60 Seconds',
#   u'BV',
#   u'$158,224,800',
#   u'$101,648,571',
#   u'6/9/00'],
#  [u'9', u'Ghost Rider', u'Sony', u'$141,218,600', u'$115,802,596', u'2/16/07'],
#  [u'10',
#   u'City of Angels',
#   u'WB',
#   u'$140,760,800',
#   u'$78,685,114',
#   u'4/10/98'],
#  [u'-', u'G-Force', u'BV', u'$134,278,900', u'$119,436,770', u'7/24/09'],
#  [u'11',
# ...

# %%
col = ['rank', 'movie_name', 'studio', 'adjusted_gross', 'adjusted_opening', 'date']
nc_movies_adj = pd.DataFrame(movie_table, columns = col)

# %%
nc_movies_adj
# Out:
#    rank                                movie_name  studio adjusted_gross  \
# 0     1        National Treasure: Book of Secrets      BV   $261,537,700
# 1     2                                  The Rock      BV   $254,489,400
# 2     3                         National Treasure      BV   $232,678,500
# 3     4                                  Face/Off    Par.   $205,228,100
# 4     5                                The Croods     Fox   $190,841,800
# 5     6                                   Con Air      BV   $184,831,400
# 6     7                                Moonstruck     MGM   $164,679,900
# 7     8                        Gone in 60 Seconds      BV   $158,224,800
# 8     9                               Ghost Rider    Sony   $141,218,600
# 9    10                            City of Angels      WB   $140,760,800
# 10    -                                   G-Force      BV   $134,278,900
# 11   11                            The Family Man    Uni.   $114,311,100
# ...

# %%
soup.find_all('table')[1].find_all('tr')[0].find_all('td')[0].find_all('tr')[1].find_all('td')[1].find_all('a')[0].get('href')
# Out:
# '/movies/?id=leftbehind2014.htm'

# %%
soup.find_all('table')[1].find_all('tr')[0].find_all('td')[0].find_all('tr')[2].find_all('td')[1].a['href']
# Out:
# '/movies/?id=joe2014.htm'

# %%
soup.find_all('table')[1].find_all('tr')[0].find_all('td')[0].find_all('tr')[2].find_all('td')[3].a['href']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-bcc30c91f97c> in <module>()
# ----> 1 soup.find_all('table')[1].find_all('tr')[0].find_all('td')[0].find_all('tr')[2].find_all('td')[3].a['href']
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %%
movie_table = [] #this is created as an empty list so we can append new items to the movie table
for x in range(1, len(all_movie_html_block)):
    movie_items = [] #this is cleared out as we reloop through the list to append new individual movie attributes
    movie_html_block = all_movie_html_block[x] #individual blocks from all_movie_html_block
    for i in range(len(movie_html_block.find_all('td'))):
        movie_attribute = movie_html_block.find_all('td')[i].text
        movie_items.append(movie_attribute)
        try:
            movie_html = movie_html_block.find_all('td')[i].a['href']
        except:
            movie_html = ""
        movie_items.append(movie_html)
    movie_table.append(movie_items)

# %%
movie_table
# Out:
# [[u'10/3/14',
#   '/schedule/?view=bydate&release=theatrical&date=2014-10-03&p=.htm',
#   u'Left Behind (2014)',
#   '/movies/?id=leftbehind2014.htm',
#   u'Free',
#   '/studio/chart/?studio=freestyle.htm',
#   u'$14,019,924',
#   '',
#   u'1,887',
#   '',
#   u'$6,300,147',
#   '',
#   u'1,825',
#   '',
#   u'41',
#   ''],
#  [u'4/11/14',
#   '/schedule/?view=bydate&release=theatrical&date=2014-04-11&p=.htm',
#   u'Joe (2014)',
#   '/movies/?id=joe2014.htm',
#   u'RAtt.',
#   '/studio/chart/?studio=roadsideattractions.htm',
#   u'$373,375',
#   '',
#   u'48',
#   '',
#   u'$105,881',
#   '',
#   u'48',
#   '',
#   u'52',
#   ''],
#  [u'3/22/13',
#   '/schedule/?view=bydate&release=theatrical&date=2013-03-22&p=.htm',
#   u'The Croods(Voice)',
#   '/movies/?id=croods.htm',
#   u'Fox',
#   '/studio/chart/?studio=fox.htm',
#   u'$187,168,425',
#   '',
#   u'4,065',
#   '',
#   u'$43,639,736',
#   '',
#   u'4,046',
#   '',
#   u'2',
#   ''],
#  [u'9/14/12',
# ...

# %%
col = ['date', 'date_url', 'movie', 'movie_url', 'studio', 'studio_rul', 'gross', 'gross_url', 'theaters_g', 'theaters_g_url', 'opening', 'opening_url', 'theaters_o', 'theaters_o_url', 'rank', 'rank_url']
nc_movies = pd.DataFrame(movie_table, columns = col)

# %%
nc_movies
# Out:
#         date                                           date_url  \
# 0    10/3/14  /schedule/?view=bydate&release=theatrical&date...
# 1    4/11/14  /schedule/?view=bydate&release=theatrical&date...
# 2    3/22/13  /schedule/?view=bydate&release=theatrical&date...
# 3    9/14/12  /schedule/?view=bydate&release=theatrical&date...
# 4    3/16/12  /schedule/?view=bydate&release=theatrical&date...
# 5    2/17/12  /schedule/?view=bydate&release=theatrical&date...
# 6   10/14/11  /schedule/?view=bydate&release=theatrical&date...
# 7    2/25/11  /schedule/?view=bydate&release=theatrical&date...
# 8     1/7/11  /schedule/?view=bydate&release=theatrical&date...
# 9    7/14/10  /schedule/?view=bydate&release=theatrical&date...
# 10   4/16/10  /schedule/?view=bydate&release=theatrical&date...
# 11  11/20/09  /schedule/?view=bydate&release=theatrical&date...
# 12  10/23/09  /schedule/?view=bydate&release=theatrical&date...
# 13   7/24/09
# ...

# %%
all_movie_html_block[1].find_all('td')[1].a['href']
# Out:
# '/movies/?id=leftbehind2014.htm'

# %%
def adj_table(all_movie_html_block_adj):
    movie_table = []
    movie_html_block = []
    movie_attribute = []
    movie_items = []
    for x in range(1, len(all_movie_html_block_adj)):
        movie_items = [] #this is cleared out as we reloop through the list to append new individual movie attributes
        movie_html_block = all_movie_html_block_adj[x] #individual blocks from all_movie_html_block
        for i in range(0, len(movie_html_block.find_all('td'))):
            movie_attribute = movie_html_block.find_all('td')[i].text
            movie_items.append(movie_attribute)
            try:
                movie_html = movie_html_block.find_all('td')[i].a['href']
            except:
                movie_html = ""
        movie_table.append(movie_items)
    return movie_table

movie_table = adj_table(all_movie_html_block_adj)

# %%
col = ['rank', 'rank_url', 'movie', 'movie_url', 'studio', 'studio_url','adjusted_gross', 'adjusted_gross_url', 'adjusted_opening', 'adjusted_opening_url', 'date', 'date_url']
nc_movies_adj = pd.DataFrame(movie_table, columns = col)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-136-cda3726bfe88> in <module>()
#       1 col = ['rank', 'rank_url', 'movie', 'movie_url', 'studio', 'studio_url','adjusted_gross', 'adjusted_gross_url', 'adjusted_opening', 'adjusted_opening_url', 'date', 'date_url']
# ----> 2 nc_movies_adj = pd.DataFrame(movie_table, columns = col)
#
# /Users/johnwalters/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     249             if len(data) > 0:
#     250                 if is_list_like(data[0]) and getattr(data[0], 'ndim', 1) == 1:
# --> 251                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     252                     columns = _ensure_index(columns)
#     253
#
# ...

# %%
movie_table
# Out:
# [[u'1',
#   u'National Treasure: Book of Secrets',
#   u'BV',
#   u'$261,537,700',
#   u'$219,964,115',
#   u'12/21/07'],
#  [u'2', u'The Rock', u'BV', u'$254,489,400', u'$134,069,511', u'6/7/96'],
#  [u'3',
#   u'National Treasure',
#   u'BV',
#   u'$232,678,500',
#   u'$173,008,894',
#   u'11/19/04'],
#  [u'4', u'Face/Off', u'Par.', u'$205,228,100', u'$112,276,146', u'6/27/97'],
#  [u'5', u'The Croods', u'Fox', u'$190,841,800', u'$187,168,425', u'3/22/13'],
#  [u'6', u'Con Air', u'BV', u'$184,831,400', u'$101,117,573', u'6/6/97'],
#  [u'7', u'Moonstruck', u'MGM', u'$164,679,900', u'$80,640,528', u'12/18/87'],
#  [u'8',
#   u'Gone in 60 Seconds',
#   u'BV',
#   u'$158,224,800',
#   u'$101,648,571',
#   u'6/9/00'],
#  [u'9', u'Ghost Rider', u'Sony', u'$141,218,600', u'$115,802,596', u'2/16/07'],
#  [u'10',
#   u'City of Angels',
#   u'WB',
#   u'$140,760,800',
#   u'$78,685,114',
#   u'4/10/98'],
#  [u'-', u'G-Force', u'BV', u'$134,278,900', u'$119,436,770', u'7/24/09'],
#  [u'11',
# ...

# %%
def adj_table(all_movie_html_block_adj):
    movie_table = []
    movie_html_block = []
    movie_attribute = []
    movie_items = []
    for x in range(1, len(all_movie_html_block_adj)):
        movie_items = [] #this is cleared out as we reloop through the list to append new individual movie attributes
        movie_html_block = all_movie_html_block_adj[x] #individual blocks from all_movie_html_block
        for i in range(len(movie_html_block.find_all('td'))):
            movie_attribute = movie_html_block.find_all('td')[i].text
            movie_items.append(movie_attribute)
        movie_table.append(movie_items)
    return movie_table

# %%
movie_table
# Out:
# [[u'1',
#   u'National Treasure: Book of Secrets',
#   u'BV',
#   u'$261,537,700',
#   u'$219,964,115',
#   u'12/21/07'],
#  [u'2', u'The Rock', u'BV', u'$254,489,400', u'$134,069,511', u'6/7/96'],
#  [u'3',
#   u'National Treasure',
#   u'BV',
#   u'$232,678,500',
#   u'$173,008,894',
#   u'11/19/04'],
#  [u'4', u'Face/Off', u'Par.', u'$205,228,100', u'$112,276,146', u'6/27/97'],
#  [u'5', u'The Croods', u'Fox', u'$190,841,800', u'$187,168,425', u'3/22/13'],
#  [u'6', u'Con Air', u'BV', u'$184,831,400', u'$101,117,573', u'6/6/97'],
#  [u'7', u'Moonstruck', u'MGM', u'$164,679,900', u'$80,640,528', u'12/18/87'],
#  [u'8',
#   u'Gone in 60 Seconds',
#   u'BV',
#   u'$158,224,800',
#   u'$101,648,571',
#   u'6/9/00'],
#  [u'9', u'Ghost Rider', u'Sony', u'$141,218,600', u'$115,802,596', u'2/16/07'],
#  [u'10',
#   u'City of Angels',
#   u'WB',
#   u'$140,760,800',
#   u'$78,685,114',
#   u'4/10/98'],
#  [u'-', u'G-Force', u'BV', u'$134,278,900', u'$119,436,770', u'7/24/09'],
#  [u'11',
# ...

# %%
def movie_table(all_movie_html_block_adj):
    movie_table = []
    movie_html_block = []
    movie_attribute = []
    movie_items = []
    for x in range(1, len(all_movie_html_block_adj)):
        movie_items = [] #this is cleared out as we reloop through the list to append new individual movie attributes
        movie_html_block = all_movie_html_block_adj[x] #individual blocks from all_movie_html_block
        for i in range(0, len(movie_html_block.find_all('td'))):
            movie_attribute = movie_html_block.find_all('td')[i].text
            movie_items.append(movie_attribute)
            try:
            	movie_html = movie_html_block.find_all('td')[i].a['href']
            except:
            	movie_html = ""
            movie_items.append(movie_html)
        movie_table.append(movie_items)
    return movie_table

movie_table1 = movie_table(all_movie_html_block)
movie_table2 = movie_table(all_movie_html_block_adj)
col = ['date', 'date_url', 'movie', 'movie_url', 'studio', 'studio_url', 'gross', 'gross_url', 'theaters_g', 'theaters_g_url', 'opening', 'opening_url', 'theaters_o', 'theaters_o_url', 'rank', 'rank_url']
nc_movies_1 = pd.DataFrame(movie_table1, columns = col)
nc_movies_1['date_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['date_url']
nc_movies_1['movie_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['movie_url']
nc_movies_1['studio_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['studio_url']
nc_movies_1['gross_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['gross_url']
nc_movies_1['theaters_g_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['theaters_g_url']
nc_movies_1['opening_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['opening_url']
nc_movies_1['theaters_o_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['theaters_o_url']
nc_movies_1['rank_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['rank_url']
col = ['rank', 'rank_url', 'movie', 'movie_url', 'studio', 'studio_url','adjusted_gross', 'adjusted_gross_url', 'adjusted_opening', 'adjusted_opening_url', 'date', 'date_url']
nc_movies_2 = pd.DataFrame(movie_table2, columns = col)
nc_movies_2['date_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['date_url']
nc_movies_2['movie_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['movie_url']
nc_movies_2['studio_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['studio_url']
nc_movies_2['gross_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['gross_url']
nc_movies_2['theaters_g_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['theaters_g_url']
nc_movies_2['opening_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['opening_url']
nc_movies_2['theaters_o_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['theaters_o_url']
nc_movies_2['rank_url'] = 'http://www.boxofficemojo.com/'+nc_movies_1['rank_url']

# %%
nc_movies_1.head()
# Out:
#       date                                           date_url  \
# 0  10/3/14  /schedule/?view=bydate&release=theatrical&date...
# 1  4/11/14  /schedule/?view=bydate&release=theatrical&date...
# 2  3/22/13  /schedule/?view=bydate&release=theatrical&date...
# 3  9/14/12  /schedule/?view=bydate&release=theatrical&date...
# 4  3/16/12  /schedule/?view=bydate&release=theatrical&date...
#
#                 movie                       movie_url studio  \
# 0  Left Behind (2014)  /movies/?id=leftbehind2014.htm   Free
# 1          Joe (2014)         /movies/?id=joe2014.htm  RAtt.
# 2   The Croods(Voice)          /movies/?id=croods.htm    Fox
# 3       Stolen (2012)      /movies/?id=stolen2012.htm    MNE
# 4     Seeking Justice  /movies/?id=seekingjustice.htm  Anch.
#
#                                           studio_rul         gross gross_url  \
# 0                /studio/chart/?studio=freestyle.htm   $14,019,924
# 1      /studio/chart/?studio=roadsideattractions.htm      $373,375
# ...

# %%
nc_movies_2.head()
# Out:
#   rank rank_url                               movie  \
# 0    1           National Treasure: Book of Secrets
# 1    2                                     The Rock
# 2    3                            National Treasure
# 3    4                                     Face/Off
# 4    5                                   The Croods
#
#                            movie_url studio  \
# 0  /movies/?id=nationaltreasure2.htm     BV
# 1               /movies/?id=rock.htm     BV
# 2   /movies/?id=nationaltreasure.htm     BV
# 3            /movies/?id=faceoff.htm   Par.
# 4             /movies/?id=croods.htm    Fox
#
#                              studio_url adjusted_gross adjusted_gross_url  \
# 0  /studio/chart/?studio=buenavista.htm   $261,537,700
# 1  /studio/chart/?studio=buenavista.htm   $254,489,400
# 2  /studio/chart/?studio=buenavista.htm   $232,678,500
# 3   /studio/chart/?studio=paramount.htm   $205,228,100
# 4         /studio/chart/?studio=fox.htm   $190,841,800
#
# ...
